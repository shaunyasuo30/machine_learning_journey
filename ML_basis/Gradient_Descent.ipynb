# %% [markdown]
# $f(x)=x^2+5sin(x)$

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

def grad(x):
  return 2*x + 5*np.cos(x)
def cost(x):
  return x**2 + 5*np.sin(x)
def myGD1(eta, x0):
  x = [x0]
  for it in range(100):
    x_new = x[-1] - eta*grad(x[-1])
    if abs(grad(x_new)) < 1e-100:
      break
    x.append(x_new)
  return (x, it)
(x1, it1) = myGD1(.1, -5)
(x2, it2) = myGD1(.1, 5)
print('Solution x1 = %.10f, cost = %f, obtained after %d iterations'%(x1[-1], cost(x1[-1]), it1))
print('Solution x2 = %.10f, cost = %f, obtained after %d iterations'%(x2[-1], cost(x2[-1]), it2))
# Out:
# Solution x1 = -1.1105105036, cost = -3.246394, obtained after 99 iterations
# Solution x2 = -1.1105105036, cost = -3.246394, obtained after 99 iterations

# %% [markdown]
# $f’(x) \approx \frac{f(x + \varepsilon) - f(x - \varepsilon)}{2\varepsilon} ~~~~$
#
# **Numerical gradient**

# %%
np.random.seed(23)
X = np.random.rand(1000, 1)
y = 4 + 3 * X + .2*np.random.randn(1000, 1) # noise added

# Building Xbar
one = np.ones((X.shape[0],1))
Xbar = np.concatenate((one, X), axis = 1)
def grad(w):
    N = Xbar.shape[0]
    return 1/N * Xbar.T.dot(Xbar.dot(w) - y)

def cost(w):
    N = Xbar.shape[0]
    return .5/N*np.linalg.norm(y - Xbar.dot(w), 2)**2;

def myGD2(w_init, grad, eta):
  w = [w_init]
  for it in range (100):
    w_new = w[-1] - eta*grad(w[-1])
    if np.linalg.norm(grad(w_new), ord=2) < 1e-3:
      break
    w.append(w_new)
  return(w, it)
w0 = [[2], [1]]
(w1, it1) = myGD2(w0, grad, 1)
print('Solution found by GD: w = ', w1[-1], '\nNumber of iterations: ', it1)
# Out:
# Solution found by GD: w =  [[3.98770949]
#  [3.01334882]]
# Number of iterations:  59

# %% [markdown]
# **Gradient with Momentum**

# %% [markdown]
# $f(x) = x^2 + 10\sin(x)$

# %%
def grad(x):
  return 2*x + 5*np.cos(x)
def has_converged(theta_new):
  return np.linalg.norm(grad(theta_new))< 1e-3
def mygdmm(theta_init, eta, gamma):
  theta = [theta_init]
  v_old = 0
  for it in range(100):
    v_new = gamma*v_old + eta*grad(theta[-1])
    theta_new = theta[-1] - v_new
    if has_converged(theta_new):
      break
    theta.append(theta_new)
    v_old = v_new
  return(theta_new, it, theta)
(x,it,theta) = mygdmm(1, 0.1, 0.9)
print('Solution found by GD = %f, obtained after %d interactions'%(x, it))
print(np.array(theta))
# Out:
# Solution found by GD = -1.110473, obtained after 95 interactions
# [ 1.          0.52984885 -0.4306987  -1.66338888 -2.39390211 -2.20595304
#  -1.29895643 -0.3571203   0.09350257 -0.01745326 -0.61374671 -1.43640942
#  -1.95651536 -1.84519492 -1.2404835  -0.610316   -0.33083553 -0.48602163
#  -0.97058389 -1.49498205 -1.70581481 -1.48709702 -1.03463241 -0.67590877
#  -0.6079451  -0.83560052 -1.20873649 -1.4799122  -1.47336743 -1.22144107
#  -0.92156517 -0.76965091 -0.83807471 -1.06648881 -1.30036438 -1.38435337
#  -1.27575513 -1.06825531 -0.90868139 -0.89072171 -1.01083918 -1.18235201
#  -1.2896177  -1.26697737 -1.14278882 -1.00999079 -0.95440867 -1.00254871
#  -1.11444295 -1.21259797 -1.23371166 -1.17134026 -1.07539659 -1.01165966
#  -1.01719176 -1.0816107  -1.1582192  -1.19600878 -1.17385506 -1.11244533
#  -1.05592246 -1.04007992 -1.07088132 -1.12410179 -1.16317324 -1.16391704
#  -1.12967571 -1.08639991 -1.06300886 -1.07247768 -1.10547875 -1.13843728
# ...
